# %% [markdown]
# <a href="https://colab.research.google.com/github/Mon-ster-Thelo/Medaase-Blood-Bank-App-Final-Year-Project-/blob/master/GoogleColab_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #System Specifications

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290460 kB
# MemFree:         8557280 kB
# MemAvailable:   12111096 kB
# Buffers:          403104 kB
# Cached:          3295448 kB
# SwapCached:            0 kB
# Active:           783788 kB
# Inactive:        3616700 kB
# Active(anon):       1352 kB
# Inactive(anon):   702284 kB
# Active(file):     782436 kB
# Inactive(file):  2914416 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               168 kB
# Writeback:             0 kB
# AnonPages:        701964 kB
# Mapped:           329016 kB
# Shmem:              1692 kB
# KReclaimable:     182368 kB
# Slab:             225824 kB
# SReclaimable:     182368 kB
# SUnreclaim:        43456 kB
# KernelStack:        5968 kB
# PageTables:        10944 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3092264 kB
# ...

# %% [markdown]
# #installing libraries

# %%
# !pip install pandas

# %%
# !import pandas as pd
# Out:
# /bin/bash: line 1: import: command not found

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Dataset.csv')

# %%
df.head()
# Out:
#      Name,Age,Gender,Country,Salary
# 0            John,25,Male,USA,50000
# 1           Emma,30,Female,UK,60000
# 2         Noah,22,Male,Canada,45000
# 3  Sophia,28,Female,Australia,70000
# 4        Liam,35,Male,Germany,80000

# %%
print('Machine Learning')
# Out:
# Machine Learning

# %%
# !ls
# Out:
# Dataset.csv  sample_data

# %% [markdown]
# #Print Function

# %%
print('machine learning')
# Out:
# machine learning

# %% [markdown]
# Concatenation

# %%
print('machine learning'  +  ' projects')
# Out:
# machine learning projects

# %%
print(68678)
# Out:
# 68678

# %%
print(6887+6473)
# Out:
# 13360

# %% [markdown]
# Basic Data types :
# 1. int
# 2. float
# 3. str

# %%
type (8)
# Out:
# int

# %%
type(8.5)
# Out:
# float

# %%
type("bitvh whegjwehjhwl")
# Out:
# str

# %% [markdown]
# #Constants and Variables

# %%
superhero = "Iron Man"
print(superhero)
# Out:
# Iron Man

# %%
superhero = "Spiderman"
print(superhero)
# Out:
# Spiderman

# %%
hero1,hero2,hero3 = "Iron man","Captain America","Thor"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron man
# Captain America
# Thor

# %%
x = y = z = 23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# #Input function

# %%
number_1 = input("Enter the first number:")
number_2 = input("Enter the second number:")

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number:23
# Enter the second number:67
# 2367

# %%
number_1 = int(input("Enter the first number:"))
number_2 = int(input("Enter the second number:"))

sum = int(number_1) + int(number_2)
print(sum)
# Out:
# Enter the first number:34
# Enter the second number:56
# 90

# %%
#changing Data type in python
num = 5
print(float(num))
# Out:
# 5.0

# %% [markdown]
# Vs

# %% [markdown]
# #Basic Data Types in Python
#
# Integer
# Floating Point
# Complex
# Boolean
# String

# %%
#integer
a = 8
print(a)
# Out:
# 8

# %%
#floating point
b = 8.5
print(b)
type(b)
# Out:
# 8.5
# float

# %%
#Complex Numbers
c= 1+3J
print(c)
type(c)
# Out:
# (1+3j)
# complex

# %% [markdown]
# #Conversion of one data type to another

# %%
#int to float
x  = 10
print(x)
type(x)
# Out:
# 10
# int

# %%
y = float(x)
print(y)
type(y)
# Out:
# 10.0
# float

# %%
#Float to int
x = 5.88
print(x)
type(x)
# Out:
# 5.88
# float

# %%
y = int(x)
print(y)
type(y)
# Out:
# 5
# int

# %% [markdown]
# Boolean
# True
# False

# %%
a = True
print(a)
type(a)
# Out:
# True
# bool

# %%
b = False
print(b)
type(b)
# Out:
# False
# bool
